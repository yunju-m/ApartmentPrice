# %% [markdown]
# <a href="https://colab.research.google.com/github/yunju-m/ApartmentPrice/blob/main/Apartment_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 우리 동네 아파트 매매 실거래가 분석 프로젝트

# %%
# !pip install PublicDataReader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 21.4 MB/s eta 0:00:00
# ...

# %%
# 1. 라이브러리 버전 확인
import PublicDataReader as pdr
print(pdr.__version__)
# Out:
# 1.0.18

# %%
# 2. 공공 데이터 포털 OpenAPI 서비스 인증키 입력하기
serviceKey = "서비스 인증키를 입력하세요."

# %%
# 3. 국톡교통부 실거래가 정보 조회 OpenAPI 세션 정의하기
# debug : True이면 모든 메시지 출력, False이면 오류 메시지만 출력 (기본값: False)
api = pdr.TransactionPrice(serviceKey)

# %%
sigungu_name = "분당구"
code = pdr.code_bdong()
code.loc[(code['시군구명'].str.contains(sigungu_name, na=False)) &
         (code['읍면동명'].isna())]
# Out:
#      시도코드  시도명  시군구코드     시군구명       법정동코드 읍면동명  동리명      생성일자 말소일자
# 5152   41  경기도  41135  성남시 분당구  4113500000  NaN  NaN  19910916  NaN

# %%
# 특정 년월 자료만 조회하기
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="41135",
    year_month="202212",
    )
df.tail()
# Out:
#      지역코드       도로명  법정동   지번               아파트  건축년도   층     전용면적     년   월  \
# 49  41135       산운로  운중동  956   산운마을8단지(부영사랑으로)  2008  11   59.612  2022  12
# 50  41135  판교원로82번길  운중동  918      산운마을13단지(태영)  2010  17   84.720  2022  12
# 51  41135      판교원로  운중동  922  산운마을11단지(판교포레라움)  2009   5   59.900  2022  12
# 52  41135      판교원로  운중동  922  산운마을11단지(판교포레라움)  2009   5   59.900  2022  12
# 53  41135  판교원로82번길  운중동  916  산운마을14단지(경남아너스빌)  2009  10  101.250  2022  12
#
#     ...  법정동본번코드  법정동부번코드 법정동시군구코드 법정동읍면동코드 법정동지번코드       일련번호  거래유형  \
# 49  ...     0956     0000    41135    11500       1  41135-434  중개거래
# 50  ...     0918     0000    41135    11500       1  41135-477  중개거래
# 51  ...     0922     0000    41135    11500       1  41135-466  중개거래
# 52  ...     0922     0000    41135    11500       1  41135-466  중개거래
# 53  ...     0916     0000    41135    11500       1  41135-456  중개거래
#
#                 중개사소재지   해제사유발생일  해제여부
# 49  경기 성남분당구, 경기 용인기흥구      None  None
# ...

# %%
# 특정 기간 자료 조회하기
df = api.get_data(
    property_type="아파트",
    trade_type="매매",
    sigungu_code="41135",
    start_year_month="202212",
    end_year_month="202301",
    )
df.tail()
# Out:
#       지역코드       도로명  법정동   지번            아파트  건축년도   층    전용면적     년  월  ...  \
# 174  41135      무지개로  구미동  221   무지개(5단지)(청구)  1995   4   85.00  2023  1  ...
# 175  41135      미금일로  구미동   88  까치마을(2단지)(주공)  1995   5   59.98  2023  1  ...
# 176  41135      무지개로  구미동  221   무지개(5단지)(청구)  1995   6   85.00  2023  1  ...
# 177  41135  판교원로82번길  운중동  918   산운마을13단지(태영)  2010   9   84.92  2023  1  ...
# 178  41135  판교원로82번길  운중동  918   산운마을13단지(태영)  2010  28  115.52  2023  1  ...
#
#      법정동본번코드  법정동부번코드 법정동시군구코드 법정동읍면동코드 법정동지번코드       일련번호  거래유형    중개사소재지  \
# 174     0221     0000    41135    11400       1  41135-188  중개거래  경기 성남분당구
# 175     0088     0000    41135    11400       1  41135-167  중개거래  경기 성남분당구
# 176     0221     0000    41135    11400       1  41135-188  중개거래  경기 성남분당구
# 177     0918     0000    41135    11500       1  41135-477  중개거래  경기 성남분당구
# 178     0918     0000    41135    11500       1  41135-477  중개거래  경기 성남분당구
#
#     해제사유발생일  해제여부
# 174    None  None
# ...

# %%
df.to_excel('result_202210.xlsx') # 파일로 저장
